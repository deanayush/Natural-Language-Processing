# %% [markdown]
# ## III. Visualization

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import re
import nltk
from nltk.tokenize import RegexpTokenizer
from nltk.tokenize import word_tokenize
from nltk.tokenize import sent_tokenize
import string
from nltk.stem.wordnet import WordNetLemmatizer
from nltk.stem import PorterStemmer
from nltk.metrics.distance  import edit_distance
from nltk.corpus import words
import os
from nltk.corpus import stopwords
from textblob import TextBlob
from wordcloud import WordCloud

# %%
data=pd.read_csv('A1_datset_processed.csv')

# %%
data.head()
# Out:
#    LABEL                                               TEXT
# 0      0                                       thread scare
# 1      1                         like sean mango  yesterday
# 2      1  work show   sooooooooooo tire sparrow sign cowboy
# 3      1  actual start  afternoon  someth  slow process ...
# 4      1                       worry  vote  stop  love much

# %% [markdown]
# ## Word Cloud for Label 1

# %%
# label 1
#l = []
#c = 0
for i in range(len(data)):
    if(data['LABEL'][i] == 1):
        #c += 1
        txt_string = data['TEXT'].tolist()
        txt_string = ''.join(map(str, txt_string))
# print(txt_string)

# %%
wc = WordCloud(width = 800, height = 800, background_color = 'white', min_font_size = 10).generate(txt_string)
plt.figure(figsize = (8, 8))
plt.imshow(wc)
plt.axis('off')
plt.tight_layout(pad = 0)
plt.savefig("WordCloud_Label_1.pdf")
plt.show();

# %% [markdown]
# ## Word Cloud for Label 0

# %%
# label 0
#l = []
#c = 0
for i in range(len(data)):
    if(data['LABEL'][i] == 0):
        #c += 1
        txt_string = data['TEXT'].tolist()
        txt_string = ''.join(map(str, txt_string))
#print(c)

# %%
wc = WordCloud(width = 800, height = 800, background_color = 'white', min_font_size = 10).generate(txt_string)
plt.figure(figsize = (8, 8))
plt.imshow(wc)
plt.axis('off')
plt.tight_layout(pad = 0)
plt.savefig("WordCloud_Label_0.pdf")
plt.show();
